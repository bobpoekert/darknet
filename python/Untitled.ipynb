# %%
from PIL import Image

# %%
import numpy as np

# %%
test_image = np.asarray(Image.open('test.jpg').convert('RGB'))

# %%
import yolo

# %%
net = yolo.yolo_net()

# %%
predictions = net.predict(test_image)

# %%
test_image.shape
# Out:
# (1780, 2048, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /Users/bob/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.imshow(test_image)

# %%
import c_yolo as cy
reload(cy)
# Out:
# <module 'c_yolo' from 'c_yolo.so'>

# %%
test_yimg = cy.Image.from_ndarray(test_image)

# %%
resized = test_yimg.resize(test_arr.shape[0]*0.3, test_arr.shape[1]*0.3)
# Out:
# 534 614

# %%
test_arr = test_yimg.to_ndarray()
plt.imshow(test_arr.astype(np.uint8))

# %%
plt.figure(figsize=(20,10))
plt.imshow(resized.to_ndarray().astype(np.uint8))

# %%
resized.to_ndarray().shape
# Out:
# (614, 534, 3)

# %%
loaded_image = cy.Image.load('test.jpg', 1780, 2048)

# %%
plt.figure(figsize=(20,10))
plt.imshow(loaded_image.to_ndarray())
